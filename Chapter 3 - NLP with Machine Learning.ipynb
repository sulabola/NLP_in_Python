# %% [markdown]
# ### NLP with Machine Learning

# %% [markdown]
# In this chapter, we discuss taks that can be done using traditional NLP methods, including rules-based, and supervised and unsupervised machine learning techniques.
